# %%
import matplotlib.pyplot as plt
import numpy as np

plt.plot([5,10,20,40,80,100], np.asarray([12,13,14,15,15,16]));
plt.title("Capacity Progression")
plt.xlabel("percentage of Training Data")
plt.ylabel("MEC");

# %%
plt.plot([5,10,20,40,80,100], np.asarray([12,13,14,15,15,16]))
plt.plot([5,10,20,40,80,100], np.asarray([5,10,20,40,80,100]))
plt.title("Capacity Progression")
plt.xlabel("percentage of Training Data")
plt.ylabel("MEC");
